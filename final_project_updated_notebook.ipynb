# %% [markdown]
# # Final Project Notebook

# %% [markdown]
# ## Introduction
# This notebook serves as the final project submission, demonstrating my understanding of data science concepts and skills.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia
# - Java

# %% [markdown]
# ## Data Science Libraries
# - NumPy
# - Pandas
# - Matplotlib
# - Scikit-Learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
# | Tool             | Description                            |
# |------------------|----------------------------------------|
# | Jupyter Notebook | Interactive computing environment      |
# | RStudio          | IDE for R programming language         |
# | Apache Hadoop    | Framework for processing large datasets|

# %% [markdown]
# ## Arithmetic Expression Examples
# This section provides examples of basic arithmetic operations like addition and multiplication.

# %%
# Multiply and add numbers
result = (5 * 3) + 7
result

# %%
# Convert minutes to hours
minutes = 150
hours = minutes / 60
hours

# %% [markdown]
# ## Objectives
# - Learn about popular data science languages
# - Understand data science libraries and tools
# - Demonstrate arithmetic operations in Python
# - Convert units using Python code
# - Share project on GitHub

# %% [markdown]
# ## Author
# Anubhav Anand
